# %% [markdown]
# <a href="https://colab.research.google.com/github/HaseebUlHassan437/pre-trained-Resnet18-and-Resnet50/blob/main/pretrained_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img_path = "/content/drive/MyDrive/cat.png"
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Set the image path
img_path = "/content/drive/MyDrive/cat.png"

# Open the image using PIL
img = Image.open(img_path)

# Display the image using matplotlib
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title("Loaded Image")
plt.show()

# %%
preds = model.predict(x)
print('predicted :' , decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# predicted : [('n02124075', 'Egyptian_cat', np.float32(0.32563627)), ('n02123045', 'tabby', np.float32(0.2756051)), ('n02123159', 'tiger_cat', np.float32(0.22302884))]
